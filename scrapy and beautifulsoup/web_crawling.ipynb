# %%
# !pip install scrapy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !scrapy startproject crawler1
# Out:
# New Scrapy project 'crawler1', using template directory '/usr/local/lib/python3.7/dist-packages/scrapy/templates/project', created in:
#     /content/crawler1
#
# You can start your first spider with:
#     cd crawler1
#     scrapy genspider example example.com

# %%
# !scrapy crawl spy
# Out:
# 2022-09-25 18:21:40 [scrapy.utils.log] INFO: Scrapy 2.6.2 started (bot: crawler1)
# 2022-09-25 18:21:40 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.14, cssselect 1.1.0, parsel 1.6.0, w3lib 2.0.1, Twisted 22.8.0, Python 3.7.14 (default, Sep  8 2022, 00:06:44) - [GCC 7.5.0], pyOpenSSL 22.1.0 (OpenSSL 3.0.5 5 Jul 2022), cryptography 38.0.1, Platform Linux-5.10.133+-x86_64-with-Ubuntu-18.04-bionic
# 2022-09-25 18:21:40 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'crawler1',
#  'NEWSPIDER_MODULE': 'crawler1.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['crawler1.spiders']}
# 2022-09-25 18:21:40 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2022-09-25 18:21:40 [scrapy.extensions.telnet] INFO: Telnet Password: 8f4f9c155d363e79
# 2022-09-25 18:21:40 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
# ...

# %%
# !scrapy shell "https://quotes.toscrape.com/page/2/"
# !resp
# Out:
# 2022-09-25 18:26:53 [scrapy.utils.log] INFO: Scrapy 2.6.2 started (bot: crawler1)
# 2022-09-25 18:26:53 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.14, cssselect 1.1.0, parsel 1.6.0, w3lib 2.0.1, Twisted 22.8.0, Python 3.7.14 (default, Sep  8 2022, 00:06:44) - [GCC 7.5.0], pyOpenSSL 22.1.0 (OpenSSL 3.0.5 5 Jul 2022), cryptography 38.0.1, Platform Linux-5.10.133+-x86_64-with-Ubuntu-18.04-bionic
# 2022-09-25 18:26:53 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'crawler1',
#  'DUPEFILTER_CLASS': 'scrapy.dupefilters.BaseDupeFilter',
#  'LOGSTATS_INTERVAL': 0,
#  'NEWSPIDER_MODULE': 'crawler1.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['crawler1.spiders']}
# 2022-09-25 18:26:53 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2022-09-25 18:26:53 [scrapy.extensions.telnet] INFO: Telnet Password: 698d3ab4c0312e75
# 2022-09-25 18:26:53 [scrapy.middleware] INFO: Enabled extensions:
# ...

# %%
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `title'
# /bin/bash: -c: line 0: `response.css(title)'
